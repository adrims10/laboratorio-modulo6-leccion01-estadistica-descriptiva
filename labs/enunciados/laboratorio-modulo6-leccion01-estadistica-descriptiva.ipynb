# %% [markdown]
# <div style="text-align: center;">
#   <img src="https://github.com/Hack-io-Data/Imagenes/blob/main/01-LogosHackio/logo_naranja@4x.png?raw=true" alt="esquema" />
# </div>
#
#
# # Laboratorio Estadistica Descriptiva
#
# ⚠️ Siempre que puedas usa graficas para apoyar tu interpretacion

# %%
# importamos las librerías que necesitamos
# Tratamiento de datos
# -----------------------------------------------------------------------
import numpy as np  
import pandas as pd 


# Visualización
# ------------------------------------------------------------------------------
import matplotlib.pyplot as plt
import seaborn as sns

# librerias para estadisticas 
# ---------------------------------------------------------------------------
import statistics as st 
from scipy import stats  
from scipy.stats import skew,kurtosis # libreria para asimetria y curtosis

# %% [markdown]
# #### Ejercicio 1:
#
# 1.  Dados los siguientes datos: [15, 21, 25, 32, 35, 45, 50, 50, 55, 60]. Crea una funcion que calcule la media, mediana y moda.

# %%
lista = [15, 21, 25, 32, 35, 45, 50, 50, 55, 60]   
df= pd.DataFrame(lista)

# %%
def calcular_estadisticas(df):
    df[0].mean()
    df[0].mode()
    df[0].median()
    print(f'la media es {df[0].mean()}')
    print(f'la moda es {df[0].mode()[0]}')
    print(f'la mediana es {df[0].median()}')
    
calcular_estadisticas(df)
# Out:
# la media es 38.8
# la moda es 50
# la mediana es 40.0

# %% [markdown]
# 2.	Interpretación de la media: ¿Qué sucede si un valor extremo, como 100, se agrega al conjunto de datos anterior? ¿Cómo cambia la media? Explica por qué sucede esto.

# %%
lista1 = [15, 21, 25, 32, 35, 45, 50, 50, 55, 60,100]   
df1= pd.DataFrame(lista1)

# %%
def calcular_estadisticas(df1):
    print(f'La media es {df1[0].mean()}')
    print(f'La moda es {df1[0].mode()[0]}')
    print(f'la mediana es {df1[0].median()}')
   

calcular_estadisticas(df)
# Out:
# La media es 38.8
# La moda es 50
# la mediana es 40.0

# %% [markdown]
# La media sube como podemos preveer puesto que al meter un valor atipico, nos distorsina la media.

# %% [markdown]
# #### Ejercicio 2:
# 1. **Cálculo de la varianza y desviación estándar**: Usando los mismos datos de arriba, calcula la **varianza** y la **desviación estándar**.

# %%
def calcular_estadisticas(df1):
    print(f'La varianza {df[0].var()}')
    print(f'La desviacion estandar {df[0].std()}')

calcular_estadisticas(df)
# Out:
# La varianza 237.2888888888889
# La desviacion estandar 15.404184135775868

# %% [markdown]
# 2. **Comparación de dispersión**: Dado otro conjunto de datos: `[18, 19, 20, 22, 24, 25, 27, 30]`, compara la **dispersión** de este grupo con el conjunto de datos anterior (del Ejercicio 1) calculando la **desviación estándar** de ambos. ¿Qué conjunto tiene mayor dispersión?

# %%
lista2=[18, 19, 20, 22, 24, 25, 27, 30]
df2= pd.DataFrame(lista2)

# %%
def calcular_estadisticas(df2):
    df2[0].std()
    print(f'La desviacion estandar {df2[0].std()}')

calcular_estadisticas(df2)
# Out:
# La desviacion estandar 4.155461122770509

# %% [markdown]
# El conjunto de datos primero es mas disperso observando las deviaciones

# %% [markdown]
# #### Ejercicio 3:
#
# 1. Usa la función correspondiente en Python para calcular la **asimetría** del conjunto de datos: `[10, 20, 20, 20, 25, 30, 35, 40]`.

# %%
lista3 = [10, 20, 20, 20, 25, 30, 35, 40]
df3= pd.DataFrame(lista3)

# %%
def calcular_estadisticas(df3):
    df3[0].skew()
    print(f'La desviacion estandar {df3[0].skew()}')

calcular_estadisticas(df3)
# Out:
# La desviacion estandar 0.15965369897316026

# %% [markdown]
# 2. Interpreta el resultado: ¿El conjunto es simétrico, sesgado a la izquierda o a la derecha?

# %% [markdown]
# Es asimetrica a la derecha tiene más peso que la cola izquierda

# %% [markdown]
# #### Ejercicio 4:
#
# 1. Calcula la **curtosis** para el conjunto de datos: `[5, 5, 5, 20, 25, 30, 30, 50]`.

# %%
lista4=[5, 5, 5, 20, 25, 30, 30, 50]
df4 =pd.DataFrame(lista4)

# %%
lista4 = [5, 5, 5, 20, 25, 30, 30, 50]
df4=pd.DataFrame(lista4)

# %%
df4.kurt()
# Out:
# 0   -0.145142
# dtype: float64

# %% [markdown]
# 2. ¿El conjunto tiene una curtosis positiva, negativa o es mesocúrtico? Explica qué implica esto sobre la forma de la distribución.

# %% [markdown]
# Es negativa o platicúrtica.
# Esto es un pico más ancho y bajo comparado con una distribución normal,sugiere que los valores  outliers son menos frecuentes.

# %%
sns.histplot(lista4, kde=True, color='red')
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# #### Ejercicio 5: Caso practico.
#
#
# Imagina que una empresa está evaluando el rendimiento de sus empleados para entender la relación entre el tiempo que dedican a su trabajo y el éxito que tienen en términos de ventas. La empresa recopila datos durante un mes, midiendo cuántas **horas trabajó** cada empleado y cuántas **ventas realizaron**. Estos datosa se encuentran en el archivo `rendimiento.csv`
#
# **Horas trabajadas**:
#    - Se midieron las horas trabajadas por un grupo de empleados. En general, la mayoría de los empleados trabajan entre 40 y 60 horas a la semana, con algunos empleados trabajando un poco menos o más.
#
#
# **Ventas realizadas**:
#    - A cada empleado también se le hizo un seguimiento de cuántas ventas realizó. Aunque las ventas están influenciadas por las horas trabajadas, hay cierta **variabilidad**: algunos empleados pueden ser más productivos y vender más en menos tiempo, mientras que otros necesitan trabajar más para alcanzar los mismos resultados.
#
#
# Resuelve los siguientes puntos:
#
#
#
# 1. **Cálculo de la media, mediana y moda**:
#    - Calcula la **media**, **mediana** y **moda** de las columnas **Horas Trabajadas** y **Ventas Realizadas**.
#    - Explica qué información proporciona cada medida en este contexto. Justifica tus conclusiones con representación de graficas.

# %%
df_csv = pd.read_csv('../datos/rendimiento.csv')

# %%
df_csv.head(2)
# Out:
#    Horas Trabajadas  Ventas Realizadas
# 0         54.967142               48.0
# 1         48.617357               47.0

# %%
df_csv =df_csv.drop(columns='ID')

# %%
media = df_csv.mean()
print('Las medias son:')
print('--------------------')
print(media)
print('Las modas son:')
print('--------------------')
moda = df_csv.mode()
print(media)
print('Las medianas son:')
print('--------------------')
mediana = df_csv.median()
print(media)
# Out:
# Las medias son:
# --------------------
# Horas Trabajadas     48.961535
# Ventas Realizadas    49.120000
# dtype: float64
# Las modas son:
# --------------------
# Horas Trabajadas     48.961535
# Ventas Realizadas    49.120000
# dtype: float64
# Las medianas son:
# --------------------
# Horas Trabajadas     48.961535
# Ventas Realizadas    49.120000
# dtype: float64

# %% [markdown]
# Observamos que las medias las modas y las medianas son iguales por lo que parece que tenemos muy pocos valores atipicos

# %%
sns.histplot(df_csv['Horas Trabajadas'], kde=True,)
sns.histplot(df_csv['Ventas Realizadas'], kde= True, color='red')
# Out:
# <Axes: xlabel='Horas Trabajadas', ylabel='Count'>

# %% [markdown]
# 3. **Cálculo de la varianza y desviación estándar**:
#    - Calcula la **varianza** y la **desviación estándar** para las columnas **Horas Trabajadas** y **Ventas Realizadas**.
#    - ¿Qué conjunto de datos es más disperso? Explica el significado de la dispersión en este caso. Justifica tus conclusiones con representación de graficas.

# %%
print(f"La varianza de ventas es {df_csv['Ventas Realizadas'].var()}")
print(f"La desviacion de ventas es {df_csv['Ventas Realizadas'].std()}")
print(f"La varianza de horas es {df_csv['Horas Trabajadas'].var()}")
print(f"La desviacion de horas es {df_csv['Horas Trabajadas'].std()}")
# Out:
# La varianza de ventas es 93.05616161616163
# La desviacion de ventas es 9.646562165671334
# La varianza de horas es 82.476989363016
# La desviacion de horas es 9.081684280078008

# %%
fig, axes = plt.subplots(1, 2)

sns.histplot(data=df_csv['Ventas Realizadas'], ax=axes[0])
sns.histplot(data=df_csv['Horas Trabajadas'], ax=axes[1])
# Out:
# <Axes: xlabel='Horas Trabajadas', ylabel='Count'>

# %% [markdown]
# La varianza es alta por lo que hay una variabilidad significativa en las ventas realizadas.
# Las ventas se desvían de la media por aproximadamente 9.65 unidades. Esto nos sigue demostrando que puede haber valores bastante atipivos en el conjunto

# %% [markdown]
# La varianza es alta por lo que hay una variabilidad significativa en las ventas realizadas.
# Las ventas se desvían de la media por aproximadamente 9.65 unidades. Esto nos sigue demostrando que puede haber valores bastante atipivos en el conjunto

# %% [markdown]
# 4. **Rango y rango intercuartílico**:
#    - Calcula el **rango** y el **rango intercuartílico** para ambas columnas.
#    - ¿Qué te dice esto sobre la variabilidad de los datos? Justifica tus conclusiones con representación de graficas.

# %%
rango = df_csv['Ventas Realizadas'].max() - df_csv['Ventas Realizadas'].min()
print(f'rango de Ventas es {rango}')
rango = df_csv['Horas Trabajadas'].max() - df_csv['Horas Trabajadas'].min()
print(f'rango de Horas {rango}')
# Out:
# rango de Ventas es 50.0
# rango de Horas 44.72023288598683

# %% [markdown]
# Los dos rangos indican una ampliud en la variabilidad de los datos unicos.

# %%
Cuartil1 = df_csv['Ventas Realizadas'].quantile(0.25)
Cuartil3= df_csv['Ventas Realizadas'].quantile(0.75)
RangoQ1 = Cuartil3- Cuartil1
print(f"El Rango intercuartilico de Ventas Realizadas es {RangoQ1}")
# Out:
# El Rango intercuartilico de Ventas Realizadas es 11.25

# %%
Cuartil1 = df_csv['Horas Trabajadas'].quantile(0.25)
Cuartil3= df_csv['Horas Trabajadas'].quantile(0.75)
RangoQ = Cuartil3- Cuartil1

print(f"El IQR de Ventas Realizadas es {RangoQ}")
# Out:
# El IQR de Ventas Realizadas es 10.06857722508515

# %% [markdown]
# 5. **Cálculo de la asimetría**:
#    - Usa la función adecuada en Python para calcular la **asimetría** de los datos de **Horas Trabajadas** y **Ventas Realizadas**.
#    - Interpreta si el conjunto de datos es **simétrico**, **sesgado a la izquierda** o **sesgado a la derecha**.

# %%
print(f"la asimetría de Ventas Realizadas es {stats.skew(df_csv['Ventas Realizadas'])}")
print(f"La asimetría de Horas Trabajadas es {stats.skew(df_csv['Horas Trabajadas'])}")
# Out:
# la asimetría de Ventas Realizadas es 0.18139072143833262
# La asimetría de Horas Trabajadas es -0.17526772024434056

# %% [markdown]
# Asimetría Positiva en Ventas Realizas: Indica que la cola derecha de la distribución es más larga o tiene más peso que la cola izquierda.La mayor parte de los valores se agrupan en el lado Izquierdo del gráfico

# %% [markdown]
# Asimetría Negativa en Horas trabajadas: Indica que la cola izquierda de la distribución es más larga o tiene más peso que la cola derecha. La mayor parte de los valores se agrupan en el lado derecho del gráfico

# %%
fig, axes = plt.subplots(1, 2)
sns.kdeplot(df_csv["Ventas Realizadas"], 
            shade=True, 
            color = "Blue",
            ax=axes[0])

plt.title("Gráfico de densidad de datos")
# ponemos nombre al eje x 
plt.xlabel("Edad")

# ponemos nombre al eje y
plt.ylabel("Densidad");

sns.kdeplot(df_csv["Horas Trabajadas"], 
            shade=True, 
            color = "Blue",
            ax=axes[1])

plt.title("Gráfico de densidad de datos")
# ponemos nombre al eje x 
plt.xlabel("Edad")

# ponemos nombre al eje y
plt.ylabel("Densidad");
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_12868\4153033248.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df_csv["Ventas Realizadas"],
# C:\Users\HP\AppData\Local\Temp\ipykernel_12868\4153033248.py:14: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df_csv["Horas Trabajadas"],

# %% [markdown]
# 6. **Cálculo de la curtosis**:
#    - Calcula la **curtosis** para ambos conjuntos de datos. ¿Los conjuntos tienen una curtosis positiva, negativa o son mesocúrticos?
#    - Explica qué implica esto sobre la forma de la distribución.

# %%
print(f"la curtosis de Ventas Realizadas es {kurtosis(df_csv['Ventas Realizadas'])}")
print(f"La curtosis de Horas Trabajadas es {kurtosis(df_csv['Horas Trabajadas'])}")
# Out:
# la curtosis de Ventas Realizadas es 0.013598589847180875
# La curtosis de Horas Trabajadas es -0.15540470774207948

# %% [markdown]
# Curtosis positiva ventas curtosis > 0: Indica que la distribución tiene colas más pesadas y un pico más alto y estrecho en comparación con una distribución normal.

# %% [markdown]
# Curtosis negativa (platicúrtica) exceso de curtosis en horas trabajadas < 0: Indica que la distribución tiene colas más ligeras y un pico más bajo y ancho en comparación con una distribución normal.

# %%
plt.figure(figsize=(8, 5))
plt.hist(df_csv['Ventas Realizadas'], color='green')
plt.axvline(df_csv['Ventas Realizadas'].mean(), color='r', linestyle='--', label='Media')
plt.axvline(df_csv['Ventas Realizadas'].median(), color='g', linestyle='-', label='Mediana')
plt.title('Distribución de Ventas Realizadas')
plt.xlabel('Ventas')
plt.ylabel('Frecuencia')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# 7. **Gráfico de dispersión**:
#    - Crea un **gráfico de dispersión** entre **Horas Trabajadas** y **Ventas Realizadas**.
#    - ¿Hay alguna correlación entre ambas variables? Explica cómo interpretar la relación entre las dos variables.

# %%
plt.figure(figsize=(10, 6))

plt.scatter(df_csv["Horas Trabajadas"], df_csv["Ventas Realizadas"],edgecolor='w', color='blue', label='Horas Trabajadas')
plt.scatter(df_csv["Horas Trabajadas"], df_csv["Ventas Realizadas"], edgecolor='w', linewidth=0.5, s=100, color='red', label='Ventas Realizadas')

plt.legend()
plt.show()

# %%
#queria poner la grafica con puntos de diferentes colores pero no me ha salido.

# %%
pearson = df_csv['Horas Trabajadas'].corr(df_csv['Ventas Realizadas'])
pearson
# Out:
# np.float64(0.8706074985434324)

# %% [markdown]
# Con la grafica podemos ver que hay correlacion positiva si crece una crece la otra.
# Observamos una correlacion fuerte cercana a 1

# %% [markdown]
# 8. **Análisis exploratorio completo**:
#    - Realiza un análisis exploratorio detallado de los datos, incluyendo todas las medidas calculadas en los ejercicios anteriores. Presenta los resultados en forma de un informe claro y visual con gráficos y tablas que resuman las características clave de los datos.

# %%
media = df_csv.mean()
print('Las medias son:')
print('--------------------')
print(media)
print('Las modas son:')
print('--------------------')
moda = df_csv.mode()
print(media)
print('Las medianas son:')
print('--------------------')
mediana = df_csv.median()
print(media)
# Out:
# Las medias son:
# --------------------
# Horas Trabajadas     48.961535
# Ventas Realizadas    49.120000
# dtype: float64
# Las modas son:
# --------------------
# Horas Trabajadas     48.961535
# Ventas Realizadas    49.120000
# dtype: float64
# Las medianas son:
# --------------------
# Horas Trabajadas     48.961535
# Ventas Realizadas    49.120000
# dtype: float64

# %% [markdown]
# Observamos que las medias las modas y las medianas son iguales por lo que parece que tenemos muy pocos valores atipicos

# %%
sns.histplot(df_csv['Horas Trabajadas'], kde=True,)
sns.histplot(df_csv['Ventas Realizadas'], kde= True, color='red')
# Out:
# <Axes: xlabel='Horas Trabajadas', ylabel='Count'>

# %%
print(f"La varianza de ventas es {df_csv['Ventas Realizadas'].var()}")
print(f"La desviacion de ventas es {df_csv['Ventas Realizadas'].std()}")
print(f"La varianza de horas es {df_csv['Horas Trabajadas'].var()}")
print(f"La desviacion de horas es {df_csv['Horas Trabajadas'].std()}")
# Out:
# La varianza de ventas es 93.05616161616163
# La desviacion de ventas es 9.646562165671334
# La varianza de horas es 82.476989363016
# La desviacion de horas es 9.081684280078008

# %%
fig, axes = plt.subplots(1, 2)

sns.histplot(data=df_csv['Ventas Realizadas'], ax=axes[0])
sns.histplot(data=df_csv['Horas Trabajadas'], ax=axes[1])
# Out:
# <Axes: xlabel='Horas Trabajadas', ylabel='Count'>

# %% [markdown]
# La varianza es alta por lo que hay una variabilidad significativa en las ventas realizadas.
# Las ventas se desvían de la media por aproximadamente 9.65 unidades. Esto nos sigue demostrando que puede haber valores bastante atipivos en el conjunto

# %% [markdown]
# La varianza es alta por lo que hay una variabilidad significativa en las ventas realizadas.
# Las ventas se desvían de la media por aproximadamente 9.65 unidades. Esto nos sigue demostrando que puede haber valores bastante atipivos en el conjunto

# %%
rango = df_csv['Ventas Realizadas'].max() - df_csv['Ventas Realizadas'].min()
print(f'rango de Ventas es {rango}')
rango = df_csv['Horas Trabajadas'].max() - df_csv['Horas Trabajadas'].min()
print(f'rango de Horas {rango}')
# Out:
# rango de Ventas es 50.0
# rango de Horas 44.72023288598683

# %% [markdown]
# Los dos rangos indican una ampliud en la variabilidad de los datos unicos.

# %%
print(f"la asimetría de Ventas Realizadas es {stats.skew(df_csv['Ventas Realizadas'])}")
print(f"La asimetría de Horas Trabajadas es {stats.skew(df_csv['Horas Trabajadas'])}")
# Out:
# la asimetría de Ventas Realizadas es 0.18139072143833262
# La asimetría de Horas Trabajadas es -0.17526772024434056

# %%
fig, axes = plt.subplots(1, 2)
sns.kdeplot(df_csv["Ventas Realizadas"], 
            shade=True, 
            color = "Blue",
            ax=axes[0])
plt.title("Gráfico de densidad de datos")
plt.xlabel("Edad")
plt.ylabel("Densidad");
sns.kdeplot(df_csv["Horas Trabajadas"], 
            shade=True, 
            color = "Blue",
            ax=axes[1])
plt.title("Gráfico de densidad de datos")

plt.xlabel("Edad")
plt.ylabel("Densidad");
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_12868\1594841319.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df_csv["Ventas Realizadas"],
# C:\Users\HP\AppData\Local\Temp\ipykernel_12868\1594841319.py:14: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df_csv["Horas Trabajadas"],

# %% [markdown]
# Asimetría Positiva en Ventas Realizas: Indica que la cola derecha de la distribución es más larga o tiene más peso que la cola izquierda.La mayor parte de los valores se agrupan en el lado Izquierdo del gráfico

# %% [markdown]
# Asimetría Negativa en Horas trabajadas: Indica que la cola izquierda de la distribución es más larga o tiene más peso que la cola derecha. La mayor parte de los valores se agrupan en el lado derecho del gráfico

# %%
plt.figure(figsize=(8, 5))
plt.hist(df_csv['Ventas Realizadas'], color='green')
plt.axvline(df_csv['Ventas Realizadas'].mean(), color='r', linestyle='--', label='Media')
plt.axvline(df_csv['Ventas Realizadas'].median(), color='g', linestyle='-', label='Mediana')
plt.title('Distribución de Ventas Realizadas')
plt.xlabel('Ventas')
plt.ylabel('Frecuencia')
plt.legend()

plt.tight_layout()
plt.show()                              #grafico de curtosis ventas

# %% [markdown]
# Grafica de curtosis de las ventas

# %%
plt.figure(figsize=(8, 5))
plt.hist(df_csv['Horas Trabajadas'], color='green')
plt.axvline(df_csv['Horas Trabajadas'].mean(), color='r', linestyle='--', label='Media')
plt.axvline(df_csv['Horas Trabajadas'].median(), color='g', linestyle='-', label='Mediana')
plt.title('Distribución Horas trabajadas')
plt.xlabel('horas')
plt.ylabel('Frecuencia')
plt.legend()

plt.tight_layout()
plt.show()                      #curtosis horas

# %%
plt.figure(figsize=(10, 6))

plt.scatter(df_csv["Horas Trabajadas"], df_csv["Ventas Realizadas"],edgecolor='w', color='blue', label='Horas Trabajadas')
plt.scatter(df_csv["Horas Trabajadas"], df_csv["Ventas Realizadas"], edgecolor='w', linewidth=0.5, s=100, color='red', label='Ventas Realizadas')

plt.legend()
plt.show()
                        #grafico de dispersion

# %%
#coeficiente de pearson
pearson = df_csv['Horas Trabajadas'].corr(df_csv['Ventas Realizadas'])
pearson
# Out:
# np.float64(0.8706074985434324)

# %% [markdown]
# Con la grafica podemos ver que hay correlacion positiva si crece una crece la otra.
# Observamos una correlacion fuerte cercana a 1
